# %%
import os
import sys
import random
import numpy as np
import pandas as pd
import cv2

# %%
import numpy as np
import pickle
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

# Import necessary items from Keras
from keras.models import Sequential
from keras.layers import Activation, Dropout, UpSampling2D
from keras.layers import Conv2DTranspose, Conv2D, MaxPooling2D
#from keras.layers.normalization import BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from keras import regularizers

# %%
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Activation,AveragePooling2D ,ReLU ,Add,Dense,Reshape,Multiply, Dropout, UpSampling2D,Conv2D,MaxPooling2D,concatenate,add,GlobalAveragePooling2D,GlobalMaxPool2D,Multiply

# %%
train_images =np.load("C:/Users/jwink/CS548/CS_548_LLDNet_winkenj/data/image_mixed.npy").astype(np.float32)
labels = np.load("C:/Users/jwink/CS548/CS_548_LLDNet_winkenj/data/label_mixed.npy").astype(np.float32)
train_images = np.array(train_images)
labels = np.array(labels)
labels = labels / 255
train_images, labels = shuffle(train_images, labels)
X_train, X_val, y_train, y_val = train_test_split(train_images, labels, test_size=0.3)
batch_size =64
epochs = 100
pool_size = (2, 2)
input_shape = X_train.shape[1:]
y_train=y_train.reshape(y_train.shape[0],80,160,1)
y_val=y_val.reshape(y_val.shape[0],80,160,1)
print(y_val.shape)
# Out:
# (4500, 80, 160, 1)

# %%
import tensorflow.keras.backend as K

def dsc(y_true, y_pred, smooth=1):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth)


def dice_loss(y_true, y_pred):
    return 1.0 - dsc(y_true, y_pred)



def IOU(y_true, y_pred):

    y_true = K.flatten(y_true)
    y_pred = K.flatten(y_pred)

    thresh = 0.5

    y_true = K.cast(K.greater_equal(y_true, thresh), 'float32')
    y_pred = K.cast(K.greater_equal(y_pred, thresh), 'float32')

    union = K.sum(K.maximum(y_true, y_pred)) + K.epsilon()
    intersection = K.sum(K.minimum(y_true, y_pred)) + K.epsilon()

    iou = intersection/union

    return iou

def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
from tensorflow.keras import layers
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.models import Model
from tensorflow.keras.applications import ResNet50,MobileNetV2
def deconv(x, kernelsize,fi):
    #fi=x.shape[-1]
    fx = Conv2DTranspose(fi, kernelsize, activation='relu', padding='same')(x)
    fx = BatchNormalization()(fx)
    fx =Conv2DTranspose(fi, kernelsize, padding='same')(fx)
    out = BatchNormalization()(fx)
    return out

# %%
def CBAM (x,r):
    
    ###### Channel Attention ##########
    f=x.shape[-1]
    a_pool = GlobalAveragePooling2D()(x)
    m_pool = GlobalMaxPool2D()(x) 
    Dense_layer1 = Dense (f // r , activation = 'relu') 
    Dense_layer2 = Dense (f, activation = 'relu') 
    avg_out = Dense_layer2 (Dense_layer1(a_pool)) 
    max_out = Dense_layer2 (Dense_layer1( m_pool))
    channel = add([ avg_out,max_out]) 
    channel = Activation('sigmoid') (channel) 
    channel = Reshape ((1,1,f)) (channel)  
    C_out = Multiply()([x,channel])
   
    
                      
    ###### Spatial Attention ########
    av_pooling=AveragePooling2D(pool_size=(1,1))(C_out)
    ma_pooling=MaxPooling2D(pool_size=(1,1))(C_out)
    spatial=concatenate([av_pooling,ma_pooling], axis = 3)
    spatial =Conv2D(1,(7,7),strides=1,padding ='same') (spatial) 
    #spatial=ASPP(x,spatial)
    
    spatial= Activation('sigmoid')(spatial)
      
    S_out = Multiply()([C_out,spatial])
    
    return S_out

# %%
from tensorflow.keras import layers
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.models import Model
from tensorflow.keras.applications import ResNet50,MobileNetV2
def resblock(x, kernelsize,fi):
    #fi=x.shape[-1]
    fx = Conv2D(fi, kernelsize, activation='relu', padding='same')(x)
    fx = BatchNormalization()(fx)
    fx =Conv2D(fi, kernelsize, padding='same')(fx)
    x=Conv2D(1,1, activation='relu', padding='same')(x)
    out = Add()([x,fx])
    out = ReLU()(out)
    out = BatchNormalization()(out)
    return out

# %%
inputs = keras.layers.Input((80,160,3))

block1=resblock(inputs,3,8)

pool1 = MaxPooling2D(pool_size=(2, 2),name="pool1")(block1)
    
block2=resblock(pool1,3,16)

pool2 = MaxPooling2D(pool_size=(2, 2),name="pool2")(block2)
    
block3=resblock(pool2,3,32)

pool3 = MaxPooling2D(pool_size=(2, 2),name="pool3")(block3)


block4=resblock(pool3,3,64)

pool4 = MaxPooling2D(pool_size=(2, 2),name="pool4")(block4)







a1=CBAM (pool1,8)

a2=CBAM (pool2,8)

a2=UpSampling2D(size = (2,2))(a2)
c1=concatenate([a1,a2], axis = 3)



a3=CBAM (pool3,8)

a4=CBAM (pool4,8)


a4=UpSampling2D(size = (2,2))(a4)
c2=concatenate([a3,a4], axis = 3)
c2=UpSampling2D(size = (2,2))(c2)








c1=UpSampling2D(size = (2,2))(c1)
D1=deconv(c1, 3,32)

c2=UpSampling2D(size = (4,4))(c2)
D2=deconv(c2, 3,16)


pool4=UpSampling2D(size = (16,16))(pool4)
D3=deconv(pool4, 3,8)




D=concatenate([D1,D2,D3], axis = 3)


O= Conv2DTranspose(1, 1, activation = 'sigmoid')(D)
model = Model(inputs, O)
datagen = ImageDataGenerator(channel_shift_range=0.2)
datagen.fit(X_train)
opt = keras.optimizers.Adam()
model.compile(optimizer=opt,  loss = "binary_crossentropy", metrics = ['dsc','accuracy', 'IOU','precision_m', 'recall_m', 'f1_m'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 80, 160, 3)  0           []
#                                 ]
#
#  conv2d (Conv2D)                (None, 80, 160, 8)   224         ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 80, 160, 8)  32          ['conv2d[0][0]']
#  alization)
#
#  conv2d_2 (Conv2D)              (None, 80, 160, 1)   4           ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 80, 160, 8)   584         ['batch_normalization[0][0]']
#
#  add (Add)                      (None, 80, 160, 8)   0           ['conv2d_2[0][0]',
#                                                                   'conv2d_1[0][0]']
#
#  re_lu (ReLU)                   (None, 80, 160, 8)   0           ['add[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 80, 160, 8)  32          ['re_lu[0][0]']
#  rmalization)
#
#  pool1 (MaxPooling2D)           (None, 40, 80, 8)    0           ['batch_normalization_1[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 40, 80, 16)   1168        ['pool1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 40, 80, 16)  64          ['conv2d_3[0][0]']
#  rmalization)
#
#  conv2d_5 (Conv2D)              (None, 40, 80, 1)    9           ['pool1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 40, 80, 16)   2320        ['batch_normalization_2[0][0]']
#
#  add_1 (Add)                    (None, 40, 80, 16)   0           ['conv2d_5[0][0]',
#                                                                   'conv2d_4[0][0]']
#
#  re_lu_1 (ReLU)                 (None, 40, 80, 16)   0           ['add_1[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 40, 80, 16)  64          ['re_lu_1[0][0]']
#  rmalization)
#
#  pool2 (MaxPooling2D)           (None, 20, 40, 16)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 20, 40, 32)   4640        ['pool2[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 20, 40, 32)  128         ['conv2d_6[0][0]']
#  rmalization)
#
#  conv2d_8 (Conv2D)              (None, 20, 40, 1)    17          ['pool2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 20, 40, 32)   9248        ['batch_normalization_4[0][0]']
#
#  add_2 (Add)                    (None, 20, 40, 32)   0           ['conv2d_8[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  re_lu_2 (ReLU)                 (None, 20, 40, 32)   0           ['add_2[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 20, 40, 32)  128         ['re_lu_2[0][0]']
#  rmalization)
#
#  pool3 (MaxPooling2D)           (None, 10, 20, 32)   0           ['batch_normalization_5[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 10, 20, 64)   18496       ['pool3[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 10, 20, 64)  256         ['conv2d_9[0][0]']
#  rmalization)
#
#  conv2d_11 (Conv2D)             (None, 10, 20, 1)    33          ['pool3[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 10, 20, 64)   36928       ['batch_normalization_6[0][0]']
#
#  add_3 (Add)                    (None, 10, 20, 64)   0           ['conv2d_11[0][0]',
#                                                                   'conv2d_10[0][0]']
#
#  re_lu_3 (ReLU)                 (None, 10, 20, 64)   0           ['add_3[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 10, 20, 64)  256         ['re_lu_3[0][0]']
#  rmalization)
#
#  pool4 (MaxPooling2D)           (None, 5, 10, 64)    0           ['batch_normalization_7[0][0]']
#
#  global_average_pooling2d_3 (Gl  (None, 64)          0           ['pool4[0][0]']
#  obalAveragePooling2D)
#
#  global_max_pooling2d_3 (Global  (None, 64)          0           ['pool4[0][0]']
#  MaxPooling2D)
#
#  global_average_pooling2d_1 (Gl  (None, 16)          0           ['pool2[0][0]']
#  obalAveragePooling2D)
#
#  global_max_pooling2d_1 (Global  (None, 16)          0           ['pool2[0][0]']
#  MaxPooling2D)
#
#  global_average_pooling2d_2 (Gl  (None, 32)          0           ['pool3[0][0]']
#  obalAveragePooling2D)
#
#  global_max_pooling2d_2 (Global  (None, 32)          0           ['pool3[0][0]']
#  MaxPooling2D)
#
#  dense_6 (Dense)                (None, 8)            520         ['global_average_pooling2d_3[0][0
#                                                                  ]',
#                                                                   'global_max_pooling2d_3[0][0]']
#
#  global_average_pooling2d (Glob  (None, 8)           0           ['pool1[0][0]']
#  alAveragePooling2D)
#
#  global_max_pooling2d (GlobalMa  (None, 8)           0           ['pool1[0][0]']
#  xPooling2D)
#
#  dense_2 (Dense)                (None, 2)            34          ['global_average_pooling2d_1[0][0
#                                                                  ]',
#                                                                   'global_max_pooling2d_1[0][0]']
#
#  dense_4 (Dense)                (None, 4)            132         ['global_average_pooling2d_2[0][0
#                                                                  ]',
#                                                                   'global_max_pooling2d_2[0][0]']
#
#  dense_7 (Dense)                (None, 64)           576         ['dense_6[0][0]',
#                                                                   'dense_6[1][0]']
#
#  dense (Dense)                  (None, 1)            9           ['global_average_pooling2d[0][0]'
#                                                                  , 'global_max_pooling2d[0][0]']
#
#  dense_3 (Dense)                (None, 16)           48          ['dense_2[0][0]',
#                                                                   'dense_2[1][0]']
#
#  dense_5 (Dense)                (None, 32)           160         ['dense_4[0][0]',
#                                                                   'dense_4[1][0]']
#
#  add_7 (Add)                    (None, 64)           0           ['dense_7[0][0]',
#                                                                   'dense_7[1][0]']
#
#  dense_1 (Dense)                (None, 8)            16          ['dense[0][0]',
#                                                                   'dense[1][0]']
#
#  add_5 (Add)                    (None, 16)           0           ['dense_3[0][0]',
#                                                                   'dense_3[1][0]']
#
#  add_6 (Add)                    (None, 32)           0           ['dense_5[0][0]',
#                                                                   'dense_5[1][0]']
#
#  activation_6 (Activation)      (None, 64)           0           ['add_7[0][0]']
#
#  add_4 (Add)                    (None, 8)            0           ['dense_1[0][0]',
#                                                                   'dense_1[1][0]']
#
#  activation_2 (Activation)      (None, 16)           0           ['add_5[0][0]']
#
#  activation_4 (Activation)      (None, 32)           0           ['add_6[0][0]']
#
#  reshape_3 (Reshape)            (None, 1, 1, 64)     0           ['activation_6[0][0]']
#
#  activation (Activation)        (None, 8)            0           ['add_4[0][0]']
#
#  reshape_1 (Reshape)            (None, 1, 1, 16)     0           ['activation_2[0][0]']
#
#  reshape_2 (Reshape)            (None, 1, 1, 32)     0           ['activation_4[0][0]']
#
#  multiply_6 (Multiply)          (None, 5, 10, 64)    0           ['pool4[0][0]',
#                                                                   'reshape_3[0][0]']
#
#  reshape (Reshape)              (None, 1, 1, 8)      0           ['activation[0][0]']
#
#  multiply_2 (Multiply)          (None, 20, 40, 16)   0           ['pool2[0][0]',
#                                                                   'reshape_1[0][0]']
#
#  multiply_4 (Multiply)          (None, 10, 20, 32)   0           ['pool3[0][0]',
#                                                                   'reshape_2[0][0]']
#
#  average_pooling2d_3 (AveragePo  (None, 5, 10, 64)   0           ['multiply_6[0][0]']
#  oling2D)
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 5, 10, 64)   0           ['multiply_6[0][0]']
#
#  multiply (Multiply)            (None, 40, 80, 8)    0           ['pool1[0][0]',
#                                                                   'reshape[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 20, 40, 16)  0           ['multiply_2[0][0]']
#  oling2D)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 20, 40, 16)  0           ['multiply_2[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 10, 20, 32)  0           ['multiply_4[0][0]']
#  oling2D)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 10, 20, 32)  0           ['multiply_4[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 5, 10, 128)   0           ['average_pooling2d_3[0][0]',
#                                                                   'max_pooling2d_3[0][0]']
#
#  average_pooling2d (AveragePool  (None, 40, 80, 8)   0           ['multiply[0][0]']
#  ing2D)
#
#  max_pooling2d (MaxPooling2D)   (None, 40, 80, 8)    0           ['multiply[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 20, 40, 32)   0           ['average_pooling2d_1[0][0]',
#                                                                   'max_pooling2d_1[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 10, 20, 64)   0           ['average_pooling2d_2[0][0]',
#                                                                   'max_pooling2d_2[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 5, 10, 1)     6273        ['concatenate_4[0][0]']
#
#  concatenate (Concatenate)      (None, 40, 80, 16)   0           ['average_pooling2d[0][0]',
#                                                                   'max_pooling2d[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 20, 40, 1)    1569        ['concatenate_1[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 10, 20, 1)    3137        ['concatenate_3[0][0]']
#
#  activation_7 (Activation)      (None, 5, 10, 1)     0           ['conv2d_15[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 40, 80, 1)    785         ['concatenate[0][0]']
#
#  activation_3 (Activation)      (None, 20, 40, 1)    0           ['conv2d_13[0][0]']
#
#  activation_5 (Activation)      (None, 10, 20, 1)    0           ['conv2d_14[0][0]']
#
#  multiply_7 (Multiply)          (None, 5, 10, 64)    0           ['multiply_6[0][0]',
#                                                                   'activation_7[0][0]']
#
#  activation_1 (Activation)      (None, 40, 80, 1)    0           ['conv2d_12[0][0]']
#
#  multiply_3 (Multiply)          (None, 20, 40, 16)   0           ['multiply_2[0][0]',
#                                                                   'activation_3[0][0]']
#
#  multiply_5 (Multiply)          (None, 10, 20, 32)   0           ['multiply_4[0][0]',
#                                                                   'activation_5[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 10, 20, 64)  0           ['multiply_7[0][0]']
#
#  multiply_1 (Multiply)          (None, 40, 80, 8)    0           ['multiply[0][0]',
#                                                                   'activation_1[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 40, 80, 16)   0           ['multiply_3[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 10, 20, 96)   0           ['multiply_5[0][0]',
#                                                                   'up_sampling2d_1[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 40, 80, 24)   0           ['multiply_1[0][0]',
#                                                                   'up_sampling2d[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 20, 40, 96)  0           ['concatenate_5[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 80, 160, 24)  0          ['concatenate_2[0][0]']
#
#  up_sampling2d_4 (UpSampling2D)  (None, 80, 160, 96)  0          ['up_sampling2d_2[0][0]']
#
#  up_sampling2d_5 (UpSampling2D)  (None, 80, 160, 64)  0          ['pool4[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 80, 160, 32)  6944       ['up_sampling2d_3[0][0]']
#  ose)
#
#  conv2d_transpose_2 (Conv2DTran  (None, 80, 160, 16)  13840      ['up_sampling2d_4[0][0]']
#  spose)
#
#  conv2d_transpose_4 (Conv2DTran  (None, 80, 160, 8)  4616        ['up_sampling2d_5[0][0]']
#  spose)
#
#  batch_normalization_8 (BatchNo  (None, 80, 160, 32)  128        ['conv2d_transpose[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 80, 160, 16)  64         ['conv2d_transpose_2[0][0]']
#  ormalization)
#
#  batch_normalization_12 (BatchN  (None, 80, 160, 8)  32          ['conv2d_transpose_4[0][0]']
#  ormalization)
#
#  conv2d_transpose_1 (Conv2DTran  (None, 80, 160, 32)  9248       ['batch_normalization_8[0][0]']
#  spose)
#
#  conv2d_transpose_3 (Conv2DTran  (None, 80, 160, 16)  2320       ['batch_normalization_10[0][0]']
#  spose)
#
#  conv2d_transpose_5 (Conv2DTran  (None, 80, 160, 8)  584         ['batch_normalization_12[0][0]']
#  spose)
#
#  batch_normalization_9 (BatchNo  (None, 80, 160, 32)  128        ['conv2d_transpose_1[0][0]']
#  rmalization)
#
#  batch_normalization_11 (BatchN  (None, 80, 160, 16)  64         ['conv2d_transpose_3[0][0]']
#  ormalization)
#
#  batch_normalization_13 (BatchN  (None, 80, 160, 8)  32          ['conv2d_transpose_5[0][0]']
#  ormalization)
#
#  concatenate_6 (Concatenate)    (None, 80, 160, 56)  0           ['batch_normalization_9[0][0]',
#                                                                   'batch_normalization_11[0][0]',
#                                                                   'batch_normalization_13[0][0]']
#
#  conv2d_transpose_6 (Conv2DTran  (None, 80, 160, 1)  57          ['concatenate_6[0][0]']
#  spose)
#
# ==================================================================================================
# Total params: 125,947
# Trainable params: 125,243
# Non-trainable params: 704
# __________________________________________________________________________________________________

# %%
model.save('C:/Users/jwink/CS548/CS_548_LLDNet_winkenj/LLDNet.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
from tensorflow.keras.models import load_model
 
# load model
model = load_model('C:/Users/jwink/CS548/CS_548_LLDNet_winkenj/LLDNet.h5',custom_objects={'dice_loss':dice_loss,'IOU':IOU,'dsc':dsc,'precision_m':precision_m, 'recall_m':recall_m, 'f1_m':f1_m})
# summarize model.

# %%
history=model.fit_generator(datagen.flow(X_train, y_train, batch_size=batch_size), steps_per_epoch=len(X_train)/batch_size,
epochs=epochs, verbose=1, validation_data=(X_val, y_val))

model.save('C:/Users/jwink/CS548/CS_548_LLDNet_winkenj/LLDNet.h5')
# Out:
# C:\Users\jwink\AppData\Local\Temp\ipykernel_54544\2800859008.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history=model.fit_generator(datagen.flow(X_train, y_train, batch_size=batch_size), steps_per_epoch=len(X_train)/batch_size,
# Epoch 1/100
# 164/164 [==============================] - 42s 184ms/step - loss: 0.1623 - dsc: 0.8003 - accuracy: 0.9229 - IOU: 0.8154 - precision_m: 0.8688 - recall_m: 0.9172 - f1_m: 0.8864 - val_loss: 0.2371 - val_dsc: 0.6814 - val_accuracy: 0.9186 - val_IOU: 0.7761 - val_precision_m: 0.8095 - val_recall_m: 0.9284 - val_f1_m: 0.8647
# Epoch 2/100
# 164/164 [==============================] - 27s 164ms/step - loss: 0.0556 - dsc: 0.9247 - accuracy: 0.9554 - IOU: 0.9179 - precision_m: 0.9591 - recall_m: 0.9448 - f1_m: 0.9518 - val_loss: 0.0703 - val_dsc: 0.8976 - val_accuracy: 0.9517 - val_IOU: 0.8967 - val_precision_m: 0.9668 - val_recall_m: 0.9132 - val_f1_m: 0.9392
# Epoch 3/100
# 164/164 [==============================] - 27s 164ms/step - loss: 0.0436 - dsc: 0.9410 - accuracy: 0.9579 - IOU: 0.9327 - precision_m: 0.9650 - recall_m: 0.9541 - f1_m: 0.9594 - val_loss: 0.0451 - val_dsc: 0.9395 - val_accuracy: 0.9570 - val_IOU: 0.9281 - val_precision_m: 0.9700 - val_recall_m: 0.9430 - val_f1_m: 0.9563
100
# 164/164 [==============================] - 27s 166ms/step - loss: 0.0166 - dsc: 0.9771 - accuracy: 0.9639 - IOU: 0.9778 - precision_m: 0.9818 - recall_m: 0.9810 - f1_m: 0.9814 - val_loss: 0.0208 - val_dsc: 0.9746 - val_accuracy: 0.9630 - val_IOU: 0.9713 - val_precision_m: 0.9790 - val_recall_m: 0.9786 - val_f1_m: 0.9788
# Epoch 90/100
# 164/164 [==============================] - 27s 167ms/step - loss: 0.0164 - dsc: 0.9773 - accuracy: 0.9640 - IOU: 0.9782 - precision_m: 0.9819 - recall_m: 0.9813 - f1_m: 0.9816 - val_loss: 0.0277 - val_dsc: 0.9679 - val_accuracy: 0.9615 - val_IOU: 0.9594 - val_precision_m: 0.9775 - val_recall_m: 0.9690 - val_f1_m: 0.9732
# Epoch 91/100
# 164/164 [==============================] - 27s 166ms/step - loss: 0.0168 - dsc: 0.9767 - accuracy: 0.9639 - IOU: 0.9772 - precision_m: 0.9816 - recall_m: 0.9807 - f1_m: 0.9811 - val_loss: 0.0205 - val_dsc: 0.9750 - val_accuracy: 0.9631 - val_IOU: 0.9719 - val_precision_m: 0.9791 - val_recall_m: 0.9791 - val_f1_m: 0.9791
# Epoch 92/100
# 164/164 [==============================] - 27s 166ms/step - loss: 0.0167 - dsc: 0.9768 - accuracy: 0.9639 - IOU: 0.9774 - precision_m: 0.9816 - recall_m: 0.9808 - f1_m: 0.9812 - val_loss: 0.0206 - val_dsc: 0.9753 - val_accuracy: 0.9630 - val_IOU: 0.9720 - val_precision_m: 0.9756 - val_recall_m: 0.9826 - val_f1_m: 0.9791
# Epoch 93/100
# 164/164 [==============================] - 27s 166ms/step - loss: 0.0174 - dsc: 0.9761 - accuracy: 0.9637 - IOU: 0.9760 - precision_m: 0.9809 - recall_m: 0.9803 - f1_m: 0.9806 - val_loss: 0.0214 - val_dsc: 0.9737 - val_accuracy: 0.9628 - val_IOU: 0.9699 - val_precision_m: 0.9785 - val_recall_m: 0.9776 - val_f1_m: 0.9780
# Epoch 94/100
# 164/164 [==============================] - 27s 166ms/step - loss: 0.0165 - dsc: 0.9770 - accuracy: 0.9640 - IOU: 0.9780 - precision_m: 0.9820 - recall_m: 0.9809 - f1_m: 0.9814 - val_loss: 0.0242 - val_dsc: 0.9734 - val_accuracy: 0.9624 - val_IOU: 0.9662 - val_precision_m: 0.9689 - val_recall_m: 0.9856 - val_f1_m: 0.9772
# Epoch 95/100
# 164/164 [==============================] - 27s 166ms/step - loss: 0.0190 - dsc: 0.9742 - accuracy: 0.9634 - IOU: 0.9730 - precision_m: 0.9795 - recall_m: 0.9790 - f1_m: 0.9792 - val_loss: 0.0205 - val_dsc: 0.9747 - val_accuracy: 0.9631 - val_IOU: 0.9715 - val_precision_m: 0.9822 - val_recall_m: 0.9758 - val_f1_m: 0.9790
# Epoch 96/100
# 164/164 [==============================] - 27s 167ms/step - loss: 0.0163 - dsc: 0.9774 - accuracy: 0.9640 - IOU: 0.9786 - precision_m: 0.9820 - recall_m: 0.9814 - f1_m: 0.9817 - val_loss: 0.0208 - val_dsc: 0.9744 - val_accuracy: 0.9629 - val_IOU: 0.9713 - val_precision_m: 0.9763 - val_recall_m: 0.9809 - val_f1_m: 0.9786
# Epoch 97/100
# 164/164 [==============================] - 28s 168ms/step - loss: 0.0160 - dsc: 0.9778 - accuracy: 0.9641 - IOU: 0.9793 - precision_m: 0.9823 - recall_m: 0.9816 - f1_m: 0.9820 - val_loss: 0.0202 - val_dsc: 0.9753 - val_accuracy: 0.9632 - val_IOU: 0.9725 - val_precision_m: 0.9799 - val_recall_m: 0.9788 - val_f1_m: 0.9794
# Epoch 98/100
# 164/164 [==============================] - 28s 170ms/step - loss: 0.0165 - dsc: 0.9773 - accuracy: 0.9640 - IOU: 0.9781 - precision_m: 0.9819 - recall_m: 0.9813 - f1_m: 0.9816 - val_loss: 0.0209 - val_dsc: 0.9751 - val_accuracy: 0.9630 - val_IOU: 0.9719 - val_precision_m: 0.9772 - val_recall_m: 0.9810 - val_f1_m: 0.9790
# Epoch 99/100
# 164/164 [==============================] - 27s 167ms/step - loss: 0.0160 - dsc: 0.9778 - accuracy: 0.9641 - IOU: 0.9792 - precision_m: 0.9823 - recall_m: 0.9816 - f1_m: 0.9820 - val_loss: 0.0210 - val_dsc: 0.9744 - val_accuracy: 0.9630 - val_IOU: 0.9711 - val_precision_m: 0.9817 - val_recall_m: 0.9757 - val_f1_m: 0.9787
# Epoch 100/100
# 164/164 [==============================] - 28s 169ms/step - loss: 0.0161 - dsc: 0.9776 - accuracy: 0.9640 - IOU: 0.9788 - precision_m: 0.9821 - recall_m: 0.9815 - f1_m: 0.9818 - val_loss: 0.0205 - val_dsc: 0.9752 - val_accuracy: 0.9631 - val_IOU: 0.9719 - val_precision_m: 0.9821 - val_recall_m: 0.9763 - val_f1_m: 0.9792

# %%
train_loss = history.history['loss']
valid_loss = history.history['val_loss']

train_acc = history.history['accuracy']
valid_acc = history.history['val_accuracy']

# %%
from numpy import savetxt
savetxt('train_loss_LLD.csv', train_loss, delimiter=',')
savetxt('valid_loss_LLD.csv', valid_loss, delimiter=',')

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(1, 2, figsize=(13,4))
axes = axes.flatten()

axes[0].plot(train_acc, label='training')
axes[0].plot(valid_acc, label='validation')
axes[0].set_title('Accuracy Curve')
axes[0].set_xlabel('epochs')
axes[0].set_ylabel('accuracy')
axes[0].legend()


axes[1].plot(train_loss, label='training')
axes[1].plot(valid_loss, label='validation')
axes[1].set_title('Loss Curve')
axes[1].set_xlabel('epochs')
axes[1].set_ylabel('loss')
axes[1].legend()

plt.show()

# %%
train_dice = history.history['dsc']
valid_dice = history.history['val_dsc']


train_IOU = history.history['IOU']
valid_IOU = history.history['val_IOU']

# %%
from numpy import savetxt
savetxt('train_dice_LLD.csv', train_dice, delimiter=',')
savetxt('valid_dice_LLD.csv', valid_dice, delimiter=',')

savetxt('train_IOU_LLD.csv', train_IOU, delimiter=',')
savetxt('valid_IOU_LLD.csv', valid_IOU, delimiter=',')

# %%
fig, axes = plt.subplots(1, 2, figsize=(20,7))
axes = axes.flatten()

axes[0].plot(train_IOU, label='training')
axes[0].plot(valid_IOU, label='validation')
axes[0].set_title('IOU Curve ')
axes[0].set_xlabel('epochs')
axes[0].set_ylabel('IOU')
axes[0].legend()


axes[1].plot(train_dice, label='training')
axes[1].plot(valid_dice, label='validation')
axes[1].set_title('Dice coefficient Curve')
axes[1].set_xlabel('epochs')
axes[1].set_ylabel('dice_coef')
axes[1].legend()

plt.show()
